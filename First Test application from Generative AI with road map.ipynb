# %%
# !pip install langchain-huggingface
# !pip install huggingface_hub # it has a repositry of your model
# !pip install transformers # we must used this transformer pipline to any model
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
sec_key = userdata.get('huggingface')
print(sec_key)
# Out:
# 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

# %% [markdown]
# how to call hugging face model with API

# %%
from langchain_huggingface import HuggingFaceEndpoint
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = sec_key

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(repo_id = repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke("What is huggingface")
# Out:
# '? ------------------ Hugging Face is a company that provides a platform for natural language processing (NLP) tasks. Their main product is the Transformers library, which is a popular open-source library for NLP tasks. The library includes pre-trained models for a variety of NLP tasks, such as text classification, language translation, and question answering, which can be fine-tuned for specific tasks. In addition to the library, Hugging Face also offers a cloud platform for deploying and scaling NLP models, as well as a marketplace for buying and selling pre-trained models.\n\nHugging Face was founded in 2016 by Thomas Wolf, Alexis Conneau, and Myle Ott, and is based in New York City. The company has raised over $60 million in funding from investors such as Accel, Lightspeed Venture Partners, and New Enterprise Associates.\n\nHow do I use Hugging Face Transformers library? --------------------------------------------------- To use the Hugging Face Transformers library, you will fir
# ...

# %%
from langchain import PromptTemplate, LLMChain
question = "how to create grokai api"
template = """Question: {question} Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question} Answer: Let's think step by step."

# %%
llmchain = LLMChain(prompt=prompt, llm=llm)
print(llmchain.invoke(question))
# Out:
# <ipython-input-10-7f2fddd33b71>:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llmchain = LLMChain(prompt=prompt, llm=llm)
# ...

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id = "gpt2"
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
pipe = pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf = HuggingFacePipeline(pipeline=pipe)

# %%
hf.invoke("how to manage a husband")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'how to manage a husband or wife"\n\nShe was quoted as saying, "We have to accept that in the case of a woman of great stature, there is the burden of family dynamics. It\'s impossible for us not to make sure that all this happens the right way."\n\nIn fact, it appears the wife can be the biggest obstacle in their marriage. In an interview with New Media, one partner added, "Now, I haven\'t married my wife," noting, "I think about two years ago'

# %%
# use huggingface with GPU
gpu_llm = HuggingFacePipeline.from_model_id(model_id="gpt2",task="text-generation",device=-1,pipline_kwargs= {"max_new_tokens":100})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-25-85f2de7d5335> in <cell line: 2>()
#       1 # use huggingface with GPU
# ----> 2 gpu_llm = HuggingFacePipeline.from_model_id(model_id="gpt2",task="text-generation",device=-1,pipline_kwargs= {"max_new_tokens":100})
#
# /usr/local/lib/python3.10/dist-packages/langchain_huggingface/llms/huggingface_pipeline.py in from_model_id(cls, model_id, task, backend, device, device_map, model_kwargs, pipeline_kwargs, batch_size, **kwargs)
#     229                 f"currently only {VALID_TASKS} are supported"
#     230             )
# --> 231         return cls(
#     232             pipeline=pipeline,
#     233             model_id=model_id,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     108     def __init__(self, *args: Any, **kwargs: Any) -> None:
# ...
